# %%
import sklearn.datasets as datasets

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier

cancer = datasets.load_breast_cancer()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=30)

knn_classifier = KNeighborsClassifier()   

knn_classifier = knn_classifier.fit(X_train, Y_train)

# %%
print('Accuracy of Train Data :', knn_classifier.score(X_train,Y_train))
print('Accuracy of Test Data :', knn_classifier.score(X_test,Y_test))
# Out:
# Accuracy of Train Data : 0.9483568075117371
# Accuracy of Test Data : 0.9230769230769231

# %%
for i in range(3,11):
  knn_classifier = KNeighborsClassifier(n_neighbors=i)   
  knn_classifier = knn_classifier.fit(X_train, Y_train)
  print(i)
  print('Accuracy of Train Data :', knn_classifier.score(X_train,Y_train))
  print('Accuracy of Test Data :', knn_classifier.score(X_test,Y_test))
# Out:
# 3
# Accuracy of Train Data : 0.9530516431924883
# Accuracy of Test Data : 0.9230769230769231
# 4
# Accuracy of Train Data : 0.9413145539906104
# Accuracy of Test Data : 0.9300699300699301
# 5
# Accuracy of Train Data : 0.9483568075117371
# Accuracy of Test Data : 0.9230769230769231
# 6
# Accuracy of Train Data : 0.9366197183098591
# Accuracy of Test Data : 0.9370629370629371
# 7
# Accuracy of Train Data : 0.9413145539906104
# Accuracy of Test Data : 0.9300699300699301
# 8
# Accuracy of Train Data : 0.9413145539906104
# Accuracy of Test Data : 0.9370629370629371
# 9
# Accuracy of Train Data : 0.9483568075117371
# Accuracy of Test Data : 0.9300699300699301
# 10
# Accuracy of Train Data : 0.9483568075117371
# Accuracy of Test Data : 0.9300699300699301
