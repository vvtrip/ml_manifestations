# %% [markdown]
# <a href="https://colab.research.google.com/github/vvtrip/ml_tryouts/blob/master/stats/3-probability_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EXPECTED VALUE - DISCRETE (aka mean of random variable)
# The expected value is calculated by multiplying each of the possible outcomes in the sample space with the 
# likelihood of their occurrence, and then summing up all the values.
# E[X] = ∫fX(x)dx (from −∞ to ​∞)
# E[X]=∑ xk * P(X=xk)

# EXPECTED VALUE - CONTINUOUS
# Definition
# Let X be a continuous random variable with range (-\infty,\infty)(−∞,∞). 
# The expected value of a continuous random variable X can be obtained as:
# E[X] = ∫fX(x)dx (from −∞ to ​∞)

# %% [markdown]
# ![var.png](data:image/png;base64,...)

# %% [markdown]
# # Discrete Distribution Functions

# %%
# The following are the most commonly used Discrete Distribution Functions:

# Binomial probability distribution
# Poisson probability distribution
# Hypergeometric probability distribution
# Multinomial probability distribution
# Negative binomial distribution

# %% [markdown]
# # Binomial Distribution

# %%
# Binomial Distribution is defined as:
# The frequency distribution of the possible number of successful outcomes in a given
# number of trials, in each of which there is the same probability of success.

# If a binomial experiment consists of n trials, and results in x successes, and if the probability 
# of success on an individual trial is p, the binomial probability is:
# nCx⋅p^x⋅(1−p)^n−x
# Mean and Variance:
# Mean(mu) = np
# Variance (sigma) = npq

# Example
# 80 % of people who purchase pet insurance are women. If 9 pet
# insurance owners are randomly selected, find the probability that precisely 6 are women.

n=9
p=0.80
k=6
from scipy import stats
probability = stats.binom.pmf(k, n, p)
print(probability)
# Out:
# 0.17616076799999997

# %% [markdown]
# # Poisson Distribution Function

# %%
# Results in outcomes that can be classified as successes or failures.
# The average number of successes (μ) that occurs in a specified region is known.

# Poisson Notations
# e: A constant which has a value that is approximately 2.71828.
# μ: The mean number of successes that occur in a specified region.
# x: The actual number of successes that occur in a specified region.

# A Poisson distribution function calculates the number of events occuring in a
# specific period of time, when given the average number of times the event occurs in that time span.

# A Poisson random variable denotes the number of successes that result from a Poisson 
# experiment. The probability distribution of a Poisson random variable is called a Poisson distribution function.

# Suppose a Poisson experiment is conducted in which the average number of successes
# within a given region is μ, then, the Poisson probability is:
# P(x;μ) = ( e^(-μ) * μ^x ) / x!

#example

# If the number of vehicles that pass through a junction on a busy road is at an average 
# rate of 300 per hour, find the probability that no vehicle passes in a given minute.

from scipy import stats
averagepass=300/60
probability=stats.poisson.pmf(0, averagepass)
print(probability)
# Out:
# 0.006737946999085467

# %% [markdown]
# # Continuous Distribution Function

# %%
# The following are the most commonly used Continuous Distribution Functions:

# Normal distribution
# Continuous Uniform distribution
# Chi-squared distribution
# F distribution
# t distribution

# %% [markdown]
# # Normal Distribution

# %%
# Normal distribution, also called Gaussian distribution, 
# the most common distribution function for independent, randomly generated variables.

# The graph of the normal distribution is characterized by two parameters: the mean, or average, 
# which is the maximum of the graph and about which the graph is always symmetric; and the standard deviation, 
# which determines the amount of dispersion away from the mean. A small standard deviation (compared with the mean) produces 
# a steep graph, whereas a large standard deviation (again compared with the mean) produces a flat graph

# 68% of values lie between mean +- 1 standard deviation
# 95% of values lie between mean +- 2 standard deviations
# 99.7% of values lie between mean +- 3 standard deviations

# a standard normal distribution has mean 0 and standard deviation of 1

# %% [markdown]
# # Continuous Uniform Distribution

# %%
# The uniform distribution (continuous) is one of the simplest probability distributions in statistics. It
# is a continuous distribution, this means that it takes values within a specified range
# The probability density function for a uniform distribution taking values in the range a to b is:
# It's a rectangle with total area = 1. Rectangle area is base * height. base is b - a. height is f(x). 
# Since (b-a) * f(x) = 1, f(x) is defined as:
# f(x) = 1/(b-a) if a <= x <= b, else 0
