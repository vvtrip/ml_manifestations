# %%
import pandas as pd
from scipy import stats
import numpy as np

# %%
# !wget https://hr-projects-assets-prod.s3.amazonaws.com/lrpqaeb14h/e186636d099c5d032901dfaf5db68852/matches.csv
# !wget https://hr-projects-assets-prod.s3.amazonaws.com/lrpqaeb14h/6f3085efd6250aa3c886059677871a29/deliveries.csv
# Out:
# --2023-08-11 17:12:44--  https://hr-projects-assets-prod.s3.amazonaws.com/lrpqaeb14h/e186636d099c5d032901dfaf5db68852/matches.csv
# Resolving hr-projects-assets-prod.s3.amazonaws.com (hr-projects-assets-prod.s3.amazonaws.com)... 54.231.161.49, 3.5.29.109, 52.216.245.44, ...
# Connecting to hr-projects-assets-prod.s3.amazonaws.com (hr-projects-assets-prod.s3.amazonaws.com)|54.231.161.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139754 (136K) [binary/octet-stream]
# Saving to: ‘matches.csv.3’
#
# matches.csv.3       100%[===================>] 136.48K  --.-KB/s    in 0.08s
#
# 2023-08-11 17:12:44 (1.62 MB/s) - ‘matches.csv.3’ saved [139754/139754]
#
# --2023-08-11 17:12:44--  https://hr-projects-assets-prod.s3.amazonaws.com/lrpqaeb14h/6f3085efd6250aa3c886059677871a29/deliveries.csv
# Resolving hr-projects-assets-prod.s3.amazonaws.com (hr-projects-assets-prod.s3.amazonaws.com)... 54.231.161.49, 3.5.29.109, 52.216.245.44, ...
# ...

# %%
deli = pd.read_csv('./deliveries.csv')
matche = pd.read_csv('./matches.csv')

# %%
matche.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deli.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# #1. In IPL many players have registered their mark by giving amazing performances consisitently.
#
# From the given datasets-
#
# -Get Suresh Raina's individual scores from each match from the seasons 2008,2010,2011,2012,2013,2015 and
# 2019 respectively.
#
# -Now get Suresh Raina's individual scores from each match in home city(Chennai) and individual scores from away cities((i.e) other than Chennai).
#
# -Now,create a random sample of 20 data with seed value of 2.
#
# -From the sample data sets perform t-test(paired) on individual runs scored by raina on home city and in
# away cities
#
# -Print the p-value

# %%
seasons = [2008,2010,2011,2012,2013,2015]
seasons_match_ids_home = matche[(matche.season.isin(seasons)) & (matche.city == 'Chennai')].id.values.tolist()
seasons_match_ids_away = matche[(matche.season.isin(seasons)) & (matche.city != 'Chennai')].id.values.tolist()

# %%
relevant_deli_home = deli[deli.match_id.isin(seasons_match_ids_home) & (deli.batsman ==  'SK Raina')]
relevant_deli_away = deli[deli.match_id.isin(seasons_match_ids_away) & (deli.batsman ==  'SK Raina')]

# %%
relevant_deli_home_runs = relevant_deli_home.groupby('match_id').batsman_runs.sum().values.tolist()
relevant_deli_away_runs = relevant_deli_away.groupby('match_id').batsman_runs.sum().values.tolist()

# %%
import random
random.seed(2)
relevant_deli_home_runs_sample = random.sample(relevant_deli_home_runs, 20)
relevant_deli_away_runs_sample = random.sample(relevant_deli_away_runs, 20)

# %%
import scipy.stats as stats
t_stat, p_val = stats.ttest_ind(relevant_deli_away_runs_sample, relevant_deli_home_runs_sample)
print('t_test_statistics is',round(t_stat,2))
print('p_value is', round(p_val,2))
# Out:
# t_test_statistics is 0.24
# p_value is 0.81

# %% [markdown]
# #2. In IPL strike rate is important where batsman having higher strike rate helps team to get more runs.
#
# From the given datasets-
#
#
# -Get Rohit Sharma's individual strike rates from each match where he played for Mumbai Indians.
#
# -Now from the above data get Rohit Sharma's individual strike rates in home city(Mumbai) and individual
# strike rates from away cities((i.e) other than Mumbai).
#
# -Now, create a random sample of 20 data with seed value of 2.
#
# -From the sample data sets perform t-test(paired) on individual runs scored by rohit on home city and in
# away cities
#
# -Formula for calculating strike rate - (batsmen runs/ball faced)*100
#
# -Print p value

# %%
relevant_match_ids = list(set(deli[(deli.batsman=='RG Sharma') & (deli.batting_team=='Mumbai Indians')].match_id.values.tolist()))

relevant_matches_home = matche[(matche.id.isin(relevant_match_ids)) & (matche.city=="Mumbai")].id.values.tolist()
relevant_matches_away = matche[(matche.id.isin(relevant_match_ids)) & (matche.city!="Mumbai")].id.values.tolist()

# %%
relevant_matches_home_deli = deli[(deli.match_id.isin(relevant_matches_home)) & (deli.batsman == 'RG Sharma')]
relevant_matches_away_deli = deli[(deli.match_id.isin(relevant_matches_away)) & (deli.batsman == 'RG Sharma')]

# %%
home_match_balls_faced = relevant_matches_home_deli.groupby('match_id').batsman.count().values.tolist()
home_match_runs_scored = relevant_matches_home_deli.groupby('match_id').batsman_runs.sum().values.tolist()

away_match_balls_faced = relevant_matches_away_deli.groupby('match_id').batsman.count().values.tolist()
away_match_runs_scored = relevant_matches_away_deli.groupby('match_id').batsman_runs.sum().values.tolist()

# %%
home_sr = [ round(((home_match_runs_scored[i]/home_match_balls_faced[i])*100),2) for i in range(len(home_match_balls_faced))]
away_sr = [ round(((away_match_runs_scored[i]/away_match_balls_faced[i])*100),2) for i in range(len(away_match_balls_faced))]

# %%
import random
random.seed(2)
home_sr_sample = random.sample(home_sr, 20)
away_sr_sample = random.sample(away_sr, 20)

t_stat, p_val = stats.ttest_ind(home_sr_sample, away_sr_sample)
print('t_test_statistics is',round(t_stat,2))
print('p_value is', round(p_val,2))
# Out:
# t_test_statistics is -0.97
# p_value is 0.34

# %% [markdown]
# ## 3.In IPL runs scored while batting first is always different from batting second and vice versa.
#
# From the given datasets-
#
# -Get individual team scores of overall matches from each match by innings.
#
# -From the above data select only first innings from all the matches.
#
# -Now,from the above data set create a random sample of 200 data with seed value of 2
#
# -Now,calculate the confidence interval range of the score having 95% confidence.
#
# -Convert the minimum and maximum confidence interval into integer.
# ​

# %%
indteaminng_df=deli.groupby(['match_id','inning'])['total_runs'].agg(['sum']).reset_index()
indteaminng_df=indteaminng_df[indteaminng_df['inning']==1]

dfinte=indteaminng_df['sum'].sample(n=200, random_state=2).reset_index()
mean, sigma = np.mean(dfinte['sum']), np.std(dfinte['sum'])


min = stats.norm.interval(0.95, loc=mean, scale=sigma)[0]
max = stats.norm.interval(0.95, loc=mean, scale=sigma)[1]
print("min",round(min,2))
print("max",round(max,2))
# Out:
# min 109.72
# max 218.55

# %% [markdown]
# # 4.In IPL different teams created impact by their performances.
#
# From the given dataset-
#
# -Get individual team scores of overall matches from each match by innings.
#
# -From the above data select only team scores of teams Chennai Super Kings,Kolkata Knight Riders and Mumbai Indians of overall matches from each match by innings.
#
# -From the above data select only first innings from all the matches.
#
# -Now, create a random sample of 100 data with seed value of 2.
#
# -From the sample data set perform one way anova test on the above teams and team scores scored by them on
# each match.
#
# -print p value

# %%
indteaminngbat_df=deli.groupby(['match_id','inning','batting_team'])['total_runs'].agg(['sum']).reset_index()
indteaminngbat_df=indteaminngbat_df[(indteaminngbat_df['batting_team']=='Chennai Super Kings') | (indteaminngbat_df['batting_team']=='Mumbai Indians') | (indteaminngbat_df['batting_team']=='Kolkata Knight Riders')]
indteaminngbat_df=indteaminngbat_df[indteaminngbat_df['inning']==1]
dfindteaminngbat_df=indteaminngbat_df.sample(n=100, random_state=2).reset_index()

chndf=dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Chennai Super Kings']
p_value = stats.f_oneway(dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Chennai Super Kings']['sum'], dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Mumbai Indians']['sum'], dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Kolkata Knight Riders']['sum'])[1]
print(p_value)
# Out:
# 0.3694414715740236

# %% [markdown]
# # 5.In IPL different teams created impact by their performances.
#
# From the given dataset-
#
# -Get individual team scores of overall matches from each match by innings.
#
# -From the above data select only team scores of teams Chennai Super Kings,Kolkata Knight Riders and Mumbai Indians of overall matches from each match by innings.
#
# -From the above data select only second innings from all the matches.
#
# -Now,create a random sample of 100 data with seed value of 2.
#
# -From the sample data set perform one way anova test on the above teams and team scores scored by them on
# each match.
#
# -print p value

# %%
indteaminngbat_df=deli.groupby(['match_id','inning','batting_team'])['total_runs'].agg(['sum']).reset_index()
indteaminngbat_df=indteaminngbat_df[(indteaminngbat_df['batting_team']=='Chennai Super Kings') | (indteaminngbat_df['batting_team']=='Mumbai Indians') | (indteaminngbat_df['batting_team']=='Kolkata Knight Riders')]
indteaminngbat_df=indteaminngbat_df[indteaminngbat_df['inning']==2]
dfindteaminngbat_df=indteaminngbat_df.sample(n=100, random_state=2).reset_index()

chndf=dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Chennai Super Kings']
p_value = stats.f_oneway(dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Chennai Super Kings']['sum'], dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Mumbai Indians']['sum'], dfindteaminngbat_df[dfindteaminngbat_df['batting_team']=='Kolkata Knight Riders']['sum'])[1]
print(p_value)
# Out:
# 0.16072720791891887
