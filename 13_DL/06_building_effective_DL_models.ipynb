# %% [markdown]
# **Bias**
#
# A model is said to be biased when it fails to learn all the important features that influences the output.
#
# It generalizes the data to such an extent that in spite of many features available to consider the model ends up considering just a few features (maybe one or two) to make its prediction.
#
# In such scenario, even the accuracy of the model on train data will be very low.
#
# **Variance**
#
# The variance problem is opposite to what we saw in bias problem.
#
# The model is said to be suffering from the variance if it learns all the features from the data including irrelevant information (also referred to as noise).
#
# This type of model performs very well on train data (sometimes with 100% accuracy) but very poorly on test data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Analyzing Performance**
#
# We can analyze the bias and variance problem from the visual plotting of the model assuming the data had only two features.
#
# But in a real scenario, the data has n features and it is hard and time-consuming to plot the data to infer the model performance.
#
# As an alternative to this before training, we need to divide the data into a train, dev (development set or validation set) and test set.
#
# By analyzing the performance of the model on these three datasets, we can infer whether the model is suffering from bias or variance.

# %% [markdown]
# In the context of machine learning and model training, the terms "development set" and "validation set" are often used interchangeably, but they can have slightly different connotations depending on the specific workflow or the preferences of the practitioners. Here's a breakdown of these terms:
#
# **Validation Set (or Development Set):**
#
# This is a subset of the data used to tune the parameters of the model, select the best model, and prevent overfitting. The validation set is used during the training process to evaluate the model's performance on unseen data and make adjustments accordingly.
# It's often used to evaluate different hyperparameters (like learning rate, regularization strength, etc.) and to perform model selection.
#
# **Development Set:**
#
# In some contexts, the term "development set" is specifically used to refer to the subset of data used to make decisions about model architecture, hyperparameters, and other choices during the model development phase. It is essentially the same as the validation set but emphasizes the development and iteration process.
# The term "development set" is commonly used in natural language processing (NLP) and other domains to highlight the ongoing process of model tuning and development.
#
# **Training Set:**
#
# This is the subset of data used to train the model. The model learns from this data by adjusting its weights and biases.
#
# **Test Set:**
#
# This is a separate subset of data used to evaluate the final performance of the trained model. It is only used once the model has been fully trained and tuned using the training and validation sets.

# %% [markdown]
# **An example for Inferencing bias and variance**
#
# Case 1:
#
# If train error more than acceptable range, e.g., 80%
# The model is highly biased.
#
# Case 2:
#
# If train error is less than dev set error, e.g., train error 2% and dev error 30%.
# The model is suffering from the variance.
#
# Case 3:
#
# If test error is much larger than train and dev error, e.g., train error 10%, dev error 10%, and test error 60%.
# The model is overfitting to both train and dev dataset.

# %% [markdown]
# **Overfitting**
#
# The model suffers from the variance when train data is not large enough.
#
# When the train data is too small, the model memorizes the data and all it knows is to recall the train data.
#
# Hence, it shows better accuracy on training data but performs poorly on unseen data (test data).
#
# This scenario is known as overfitting.

# %% [markdown]
# **Overcome overfitting**
#
# One way to overcome overfitting is to **get more data samples** for training.
# But this turns out to be expensive in terms of both time and cost.
#
# Given this situation, we can improve the performance by applying the technique called **Regularization.**

# %% [markdown]
# **Regularization**
#
# During overfitting, the model fails to generalize its predictions since it allocates larger weights to irrelevant features (also known as noise).
#
# Regularization penalizes the model when weights tend to go too large by adding an extra term to cost function called regularization term.
#
# **Regularization term is the function of weight.**
#
# There are two types of regularization called L1 regularization and L2 regularization.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](attachment:5d120838-e874-4560-a291-3cb59d8bfc33.png)

# %% [markdown]
# ![image.png](attachment:f7caa5fc-6ebe-4d81-9552-47dc87c48bee.png)

# %% [markdown]
# ![image.png](attachment:3e9b180d-696e-4aad-bae8-2ce32ccc8d54.png)

# %% [markdown]
# ![image.png](attachment:a680f233-da7d-4f3d-9790-0ebd7eb9ff43.png)

# %% [markdown]
# ![image.png](attachment:e5c8292c-c768-463e-99dd-cf266ea00324.png)

# %% [markdown]
# ![image.png](attachment:8207c647-8d9e-4278-8804-c067f255b685.png)
