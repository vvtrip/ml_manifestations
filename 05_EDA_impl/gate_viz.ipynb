# %% [markdown]
# <a href="https://colab.research.google.com/github/vvtrip/ml_manifestations/blob/master/05_EDA_impl/gate_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/gate.csv')
df
# Out:
#      code                                        branch  registered  appeared  \
# 0      AE                         Aerospace Engineering        6931      5255
# 1      AG                      Agricultural Engineering        2777      2362
# 2      AR                     Architecture and Planning       11450      9080
# 3      BM                        Biomedical Engineering        2345      1860
# 4      BT                                 Biotechnology       21210     17078
# 5      CE                             Civil Engineering      108136     85869
# 6      CH                          Chemical Engineering       16930     13937
# 7      CS   Computer Science and Information Technology      152652    123967
# 8      CY                                     Chemistry       35382     26825
# 9      DA      Data Science and Artificial Intelligence       52493     39210
# 10     EC     Electronics and Communication Engineering       78157     63092
# ...

# %%
df.describe()
# Out:
#           registered       appeared  apppercent        gen        obc  \
# count      36.000000      36.000000   36.000000  36.000000  36.000000
# mean    22951.083333   18147.000000   76.556823  34.133333  30.686111
# std     35123.005287   28238.860982    5.187868   8.198258   7.381527
# min       368.000000     277.000000   63.612467  25.000000  22.500000
# 25%      2748.500000    2234.250000   74.234144  26.375000  23.700000
# 50%      7042.500000    5414.500000   77.422329  33.000000  29.650000
# 75%     22526.250000   17873.000000   80.584338  39.725000  35.700000
# max    152652.000000  123967.000000   85.055816  52.700000  47.400000
#
#             scst
# count  36.000000
# mean   22.711111
# std     5.474396
# min    16.600000
# 25%    17.550000
# 50%    21.950000
# 75%    26.400000
# max    35.100000

# %%
df['registered'].plot()
# Out:
# <Axes: >

# %%
df['appeared'].plot()
# Out:
# <Axes: >

# %%
df['apppercent'].plot()
# Out:
# <Axes: >

# %%
df['apppercent'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# <ipython-input-9-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             registered  appeared  apppercent       gen       obc      scst
# registered    1.000000  0.999701    0.325359 -0.376230 -0.376737 -0.375478
# appeared      0.999701  1.000000    0.332396 -0.377763 -0.378235 -0.376983
# apppercent    0.325359  0.332396    1.000000 -0.259281 -0.258543 -0.258936
# gen          -0.376230 -0.377763   -0.259281  1.000000  0.999990  0.999986
# obc          -0.376737 -0.378235   -0.258543  0.999990  1.000000  0.999976
# scst         -0.375478 -0.376983   -0.258936  0.999986  0.999976  1.000000
